# %% [markdown]
# # 네이버

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\haeunseo\appdata\local\programs\python\python310\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\haeunseo\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import os
import openpyxl

# %%
excel_file = 'C:/Users/HAEUNSEO/easy_python/BDA/내부공모전/2305_네이버외부몰data2.xlsx'
sheet_names = ['23051주차_네이버', '23052주차_네이버', '23053주차_네이버','23054주차_네이버','23055주차_네이버']

# %%
# 각 시트를 데이터프레임으로 읽어 리스트에 저장
dfs = [pd.read_excel(excel_file, sheet_name=sheet_name) for sheet_name in sheet_names]

# %%
# concat을 사용하여 데이터프레임들을 합치기
merged_df = pd.concat(dfs)
merged_df
# Out:
#                   자사주문번호             거래처       주문일 사은품여부     출고예정일 주문/배송상태  \
# 0      43262630508074106  외부몰_직거래_네이버(신)  20230505     N  20230512   배송 완료
# 1      43262630508074106  외부몰_직거래_네이버(신)  20230505     N  20230512   배송 완료
# 2      43262630508074106  외부몰_직거래_네이버(신)  20230505     N  20230512   배송 완료
# 3      43262630508074106  외부몰_직거래_네이버(신)  20230505     N  20230512   배송 완료
# 4      43262630508071469  외부몰_직거래_네이버(신)  20230506     N  20230509   배송 완료
# ...                  ...             ...       ...   ...       ...     ...
# 29817  43262630528427534  외부몰_직거래_네이버(신)  20230528     N  20230530   배송 완료
# 29818  43262630528427534  외부몰_직거래_네이버(신)  20230528     N  20230530   배송 완료
# 29819  43262630528427533  외부몰_직거래_네이버(신)  20230528     N  20230529   배송 완료
# 29820  43262630528427533  외부몰_직거래_네이버(신)  20230528     N  20230529   배송 완료
# 29821  43262630528427532  외부몰_직거래_네이버(신)  20230528     N  20230530   배송 완료
#
#       클레임 상태              운송장등록일자  상품순번                      상품명  ...   상품유형  \
# 0      반품처리중  2023-05-08 11:42:03     1       명가 초사리곱창돌김 25gX2EA  ...  단일 상품
# 1      반품처리중  2023-05-08 11:42:03     2       우리쌀로만든태양초 골드고추장2kg  ...  단일 상품
# 2      반품처리중  2023-05-08 11:42:03     3            백설 소면 900Gx3개  ...  묶음 상품
# 3      반품처리중  2023-05-08 11:42:03     4      [네이버] 하선정 멸치액젓 400g  ...  단일 상품
# 4          -  2023-05-08 11:57:04     1  백설 갈색설탕 3KGx6개 (총 18KG)  ...  묶음 상품
# ...      ...                  ...   ...                      ...  ...    ...
# 29817      -  2023-05-28 06:18:03     1        햇반솥반 전 제품(8종) 체험팩  ...  복합 상품
# 29818      -  2023-05-28 06:18:03     2               햇반 210G 6개  ...  단일 상품
# 29819      -  2023-05-28 14:30:01     1       비비고 차돌된장찌개 460Gx5개  ...  묶음 상품
# 29820      -  2023-05-28 14:30:01     2     비비고 돼지고기김치찌개 460Gx5개  ...  묶음 상품
# 29821      -  2023-05-29 04:39:05     1    다담 순두부찌개 양념 140G x12개  ...  묶음 상품
#
#        상품타입    매출액                        자재명  초기자재수량 주문수량  취소수량  반품수량   배송유형  \
# 0        일반      0  씨제이/명가 초사리곱창돌김 25G*2EA/상온       1    0     0     1   택배배송
# 1        일반      0         우리쌀태양초고추장2KG/PP/상온       1    0     0     1   택배배송
# 2        일반      0           백설/백설 소면 900G/상온       3    0     0     3   택배배송
# 3        일반      0                하선정멸치액젓400g       1    0     0     1   택배배송
# 4        일반  34110            갈색설탕3KG(6개입)/상온       6    6     0     0   택배배송
# ...     ...    ...                        ...     ...  ...   ...   ...    ...
# 29817    일반   3841        솥반 불고기버섯영양밥 200G/상온       1    1     0     0   택배배송
# 29818    일반  11460                 햇반210g*6EA       2    2     0     0   택배배송
# 29819    일반  21510     비비고/차돌된장찌개 460G_18입/상온       5    5     0     0  네이버위탁
# 29820    일반  21800   비비고/돼지고기김치찌개 460G_18입/상온       5    5     0     0  네이버위탁
# 29821    일반  27520     다담/순두부찌개양념 140G/24입/냉장      24   24     0     0   택배배송
#
#            마감구분
# 0            상온
# 1            상온
# 2            상온
# 3            상온
# 4            상온
# ...         ...
# 29817        상온
# 29818        상온
# 29819  풀필먼트(상온)
# 29820  풀필먼트(상온)
# 29821        냉동
#
# [152458 rows x 22 columns]

# %% [markdown]
# # 1. 주문일 => 매출액 비교

# %%
merged_df.sort_values(by='주문일',ascending=True)
# Out:
#                   자사주문번호             거래처       주문일 사은품여부     출고예정일 주문/배송상태  \
# 18815  43262630501963875  외부몰_직거래_네이버(신)  20230501     N  20230502   배송 완료
# 19412  43262630501961510  외부몰_직거래_네이버(신)  20230501     N  20230502   배송 완료
# 19413  43262630501961510  외부몰_직거래_네이버(신)  20230501     N  20230502   배송 완료
# 19414  43262630501961509  외부몰_직거래_네이버(신)  20230501     N  20230502   배송 완료
# 19415  43262630501961508  외부몰_직거래_네이버(신)  20230501     N  20230502   배송 완료
# ...                  ...             ...       ...   ...       ...     ...
# 3766   43262630531503672  외부몰_직거래_네이버(신)  20230531     N  20230601   배송 완료
# 3767   43262630531503671  외부몰_직거래_네이버(신)  20230531     N  20230601   배송 완료
# 3768   43262630531503670  외부몰_직거래_네이버(신)  20230531     N  20230601   배송 완료
# 3760   43262630531503675  외부몰_직거래_네이버(신)  20230531     N  20230601   배송 완료
# 3479   43262630531504809  외부몰_직거래_네이버(신)  20230531     N  20230601   배송 완료
#
#       클레임 상태              운송장등록일자  상품순번  \
# 18815      -  2023-05-01 21:30:01     1
# 19412      -  2023-05-01 21:10:00     1
# 19413      -  2023-05-01 21:10:00     1
# 19414      -  2023-05-01 18:40:01     1
# 19415      -  2023-05-01 18:40:01     2
# ...      ...                  ...   ...
# 3766       -  2023-05-31 15:33:11     1
# 3767       -  2023-05-31 16:30:02     1
# 3768       -  2023-05-31 16:30:02     1
# 3760       -  2023-05-31 15:33:11     1
# 3479       -  2023-05-31 15:24:02     1
#
#                                                  상품명  ...   상품유형  상품타입    매출액  \
# 18815                         [스토어팜] 해찬들 구수한 집된장 3kg  ...  단일 상품    일반  19200
# 19412                        현미귀리곤약밥 16개+귀리흑미곤약밥 16개  ...  복합 상품    일반  29400
# 19413                        현미귀리곤약밥 16개+귀리흑미곤약밥 16개  ...  복합 상품    일반  29400
# 19414                                    햇반 210Gx24개  ...  단일 상품    일반  24000
# 19415                               [네이버] 햇반210Gx36개  ...  묶음 상품    일반  30420
# ...                                              ...  ...    ...   ...    ...
# 3766                                  스팸클래식 200Gx10개  ...  묶음 상품    일반  24900
# 3767                  햇반 100%현미로 지은밥 130Gx36개 (1BOX)  ...  묶음 상품    일반  33900
# 3768                  햇반 100%현미로 지은밥 130Gx36개 (1BOX)  ...  묶음 상품    일반  35010
# 3760                               햇반 발아현미밥 210Gx36개  ...  묶음 상품    일반  40780
# 3479   [복합_마켓전략] 햇반 컵반 한끼간편 BIG세트 (인기메뉴 4종 2개씩 총 8개)  ...  복합 상품    일반   6725
#
#                                자재명  초기자재수량 주문수량  취소수량  반품수량   배송유형      마감구분
# 18815             구수한집된장3KG/15년/상온       1    1     0     0  네이버위탁  풀필먼트(상온)
# 19412           햇반 현미귀리곤약밥 150G/상온      16   16     0     0  네이버위탁  풀필먼트(상온)
# 19413           햇반 귀리흑미곤약밥 150G/상온      16   16     0     0  네이버위탁  풀필먼트(상온)
# 19414             햇반210G*24(1입)/상온       1    1     0     0  네이버위탁  풀필먼트(상온)
# 19415            햇반210G(36입)NEW/상온      36   36     0     0  네이버위탁  풀필먼트(상온)
# ...                            ...     ...  ...   ...   ...    ...       ...
# 3766                스팸 클래식 200G/상온      10   10     0     0   택배배송        상온
# 3767   햇반 100%현미로 지은 밥 130G_GHP/상온      36   36     0     0  네이버위탁  풀필먼트(상온)
# 3768   햇반 100%현미로 지은 밥 130G_GHP/상온      36   36     0     0  네이버위탁  풀필먼트(상온)
# 3760      햇반 발아현미밥 210G 낱개(36입)/상온      36   36     0     0   택배배송        상온
# 3479         햇반/컵반BIG스팸김치덮밥328G/상온       2    2     0     0   택배배송        상온
#
# [152458 rows x 22 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152458 entries, 0 to 29821
# Data columns (total 22 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   자사주문번호   152458 non-null  int64
#  1   거래처      152458 non-null  object
#  2   주문일      152458 non-null  int64
#  3   사은품여부    152458 non-null  object
#  4   출고예정일    152458 non-null  int64
#  5   주문/배송상태  152458 non-null  object
#  6   클레임 상태   152458 non-null  object
#  7   운송장등록일자  148147 non-null  object
#  8   상품순번     152458 non-null  int64
#  9   상품명      152458 non-null  object
#  10  상품수량     152458 non-null  int64
#  11  덤상품수량    152458 non-null  int64
#  12  상품유형     151753 non-null  object
#  13  상품타입     151753 non-null  object
#  14  매출액      152458 non-null  int64
#  15  자재명      151753 non-null  object
#  16  초기자재수량   152458 non-null  int64
#  17  주문수량     152458 non-null  int64
#  18  취소수량     152458 non-null  int64
#  19  반품수량     152458 non-null  int64
#  20  배송유형     152458 non-null  object
#  21  마감구분     152458 non-null  object
# dtypes: int64(11), object(11)
# memory usage: 26.8+ MB

# %%
merged_df.isna().sum()
# Out:
# 자사주문번호        0
# 거래처           0
# 주문일           0
# 사은품여부         0
# 출고예정일         0
# 주문/배송상태       0
# 클레임 상태        0
# 운송장등록일자    4311
# 상품순번          0
# 상품명           0
# 상품수량          0
# 덤상품수량         0
# 상품유형        705
# 상품타입        705
# 매출액           0
# 자재명         705
# 초기자재수량        0
# 주문수량          0
# 취소수량          0
# 반품수량          0
# 배송유형          0
# 마감구분          0
# dtype: int64

# %% [markdown]
# ### 요일별 어떤 상품이 가장 잘 나가는지
# (주문일=> 요일처리해서 상품명별 매출액 비교)

# %%
from datetime import datetime

# %%
# '주문일'이 int형이므로 datetime으로 변환
merged_df['주문일'] = pd.to_datetime(merged_df['주문일'], format='%Y%m%d')
merged_df
# Out:
#                   자사주문번호             거래처        주문일 사은품여부     출고예정일 주문/배송상태  \
# 0      43262630508074106  외부몰_직거래_네이버(신) 2023-05-05     N  20230512   배송 완료
# 1      43262630508074106  외부몰_직거래_네이버(신) 2023-05-05     N  20230512   배송 완료
# 2      43262630508074106  외부몰_직거래_네이버(신) 2023-05-05     N  20230512   배송 완료
# 3      43262630508074106  외부몰_직거래_네이버(신) 2023-05-05     N  20230512   배송 완료
# 4      43262630508071469  외부몰_직거래_네이버(신) 2023-05-06     N  20230509   배송 완료
# ...                  ...             ...        ...   ...       ...     ...
# 29817  43262630528427534  외부몰_직거래_네이버(신) 2023-05-28     N  20230530   배송 완료
# 29818  43262630528427534  외부몰_직거래_네이버(신) 2023-05-28     N  20230530   배송 완료
# 29819  43262630528427533  외부몰_직거래_네이버(신) 2023-05-28     N  20230529   배송 완료
# 29820  43262630528427533  외부몰_직거래_네이버(신) 2023-05-28     N  20230529   배송 완료
# 29821  43262630528427532  외부몰_직거래_네이버(신) 2023-05-28     N  20230530   배송 완료
#
#       클레임 상태              운송장등록일자  상품순번                      상품명  ...   상품유형  \
# 0      반품처리중  2023-05-08 11:42:03     1       명가 초사리곱창돌김 25gX2EA  ...  단일 상품
# 1      반품처리중  2023-05-08 11:42:03     2       우리쌀로만든태양초 골드고추장2kg  ...  단일 상품
# 2      반품처리중  2023-05-08 11:42:03     3            백설 소면 900Gx3개  ...  묶음 상품
# 3      반품처리중  2023-05-08 11:42:03     4      [네이버] 하선정 멸치액젓 400g  ...  단일 상품
# 4          -  2023-05-08 11:57:04     1  백설 갈색설탕 3KGx6개 (총 18KG)  ...  묶음 상품
# ...      ...                  ...   ...                      ...  ...    ...
# 29817      -  2023-05-28 06:18:03     1        햇반솥반 전 제품(8종) 체험팩  ...  복합 상품
# 29818      -  2023-05-28 06:18:03     2               햇반 210G 6개  ...  단일 상품
# 29819      -  2023-05-28 14:30:01     1       비비고 차돌된장찌개 460Gx5개  ...  묶음 상품
# 29820      -  2023-05-28 14:30:01     2     비비고 돼지고기김치찌개 460Gx5개  ...  묶음 상품
# 29821      -  2023-05-29 04:39:05     1    다담 순두부찌개 양념 140G x12개  ...  묶음 상품
#
#        상품타입    매출액                        자재명  초기자재수량 주문수량  취소수량  반품수량   배송유형  \
# 0        일반      0  씨제이/명가 초사리곱창돌김 25G*2EA/상온       1    0     0     1   택배배송
# 1        일반      0         우리쌀태양초고추장2KG/PP/상온       1    0     0     1   택배배송
# 2        일반      0           백설/백설 소면 900G/상온       3    0     0     3   택배배송
# 3        일반      0                하선정멸치액젓400g       1    0     0     1   택배배송
# 4        일반  34110            갈색설탕3KG(6개입)/상온       6    6     0     0   택배배송
# ...     ...    ...                        ...     ...  ...   ...   ...    ...
# 29817    일반   3841        솥반 불고기버섯영양밥 200G/상온       1    1     0     0   택배배송
# 29818    일반  11460                 햇반210g*6EA       2    2     0     0   택배배송
# 29819    일반  21510     비비고/차돌된장찌개 460G_18입/상온       5    5     0     0  네이버위탁
# 29820    일반  21800   비비고/돼지고기김치찌개 460G_18입/상온       5    5     0     0  네이버위탁
# 29821    일반  27520     다담/순두부찌개양념 140G/24입/냉장      24   24     0     0   택배배송
#
#            마감구분
# 0            상온
# 1            상온
# 2            상온
# 3            상온
# 4            상온
# ...         ...
# 29817        상온
# 29818        상온
# 29819  풀필먼트(상온)
# 29820  풀필먼트(상온)
# 29821        냉동
#
# [152458 rows x 22 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152458 entries, 0 to 29821
# Data columns (total 22 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   자사주문번호   152458 non-null  int64
#  1   거래처      152458 non-null  object
#  2   주문일      152458 non-null  datetime64[ns]
#  3   사은품여부    152458 non-null  object
#  4   출고예정일    152458 non-null  int64
#  5   주문/배송상태  152458 non-null  object
#  6   클레임 상태   152458 non-null  object
#  7   운송장등록일자  148147 non-null  object
#  8   상품순번     152458 non-null  int64
#  9   상품명      152458 non-null  object
#  10  상품수량     152458 non-null  int64
#  11  덤상품수량    152458 non-null  int64
#  12  상품유형     151753 non-null  object
#  13  상품타입     151753 non-null  object
#  14  매출액      152458 non-null  int64
#  15  자재명      151753 non-null  object
#  16  초기자재수량   152458 non-null  int64
#  17  주문수량     152458 non-null  int64
#  18  취소수량     152458 non-null  int64
#  19  반품수량     152458 non-null  int64
#  20  배송유형     152458 non-null  object
#  21  마감구분     152458 non-null  object
# dtypes: datetime64[ns](1), int64(10), object(11)
# memory usage: 26.8+ MB

# %%
# 요일에 대한 정보 추출
merged_df['Day_of_Week'] = merged_df['주문일'].dt.day_name()
merged_df
# Out:
#                   자사주문번호             거래처        주문일 사은품여부     출고예정일 주문/배송상태  \
# 0      43262630508074106  외부몰_직거래_네이버(신) 2023-05-05     N  20230512   배송 완료
# 1      43262630508074106  외부몰_직거래_네이버(신) 2023-05-05     N  20230512   배송 완료
# 2      43262630508074106  외부몰_직거래_네이버(신) 2023-05-05     N  20230512   배송 완료
# 3      43262630508074106  외부몰_직거래_네이버(신) 2023-05-05     N  20230512   배송 완료
# 4      43262630508071469  외부몰_직거래_네이버(신) 2023-05-06     N  20230509   배송 완료
# ...                  ...             ...        ...   ...       ...     ...
# 29817  43262630528427534  외부몰_직거래_네이버(신) 2023-05-28     N  20230530   배송 완료
# 29818  43262630528427534  외부몰_직거래_네이버(신) 2023-05-28     N  20230530   배송 완료
# 29819  43262630528427533  외부몰_직거래_네이버(신) 2023-05-28     N  20230529   배송 완료
# 29820  43262630528427533  외부몰_직거래_네이버(신) 2023-05-28     N  20230529   배송 완료
# 29821  43262630528427532  외부몰_직거래_네이버(신) 2023-05-28     N  20230530   배송 완료
#
#       클레임 상태              운송장등록일자  상품순번                      상품명  ...  상품타입  \
# 0      반품처리중  2023-05-08 11:42:03     1       명가 초사리곱창돌김 25gX2EA  ...    일반
# 1      반품처리중  2023-05-08 11:42:03     2       우리쌀로만든태양초 골드고추장2kg  ...    일반
# 2      반품처리중  2023-05-08 11:42:03     3            백설 소면 900Gx3개  ...    일반
# 3      반품처리중  2023-05-08 11:42:03     4      [네이버] 하선정 멸치액젓 400g  ...    일반
# 4          -  2023-05-08 11:57:04     1  백설 갈색설탕 3KGx6개 (총 18KG)  ...    일반
# ...      ...                  ...   ...                      ...  ...   ...
# 29817      -  2023-05-28 06:18:03     1        햇반솥반 전 제품(8종) 체험팩  ...    일반
# 29818      -  2023-05-28 06:18:03     2               햇반 210G 6개  ...    일반
# 29819      -  2023-05-28 14:30:01     1       비비고 차돌된장찌개 460Gx5개  ...    일반
# 29820      -  2023-05-28 14:30:01     2     비비고 돼지고기김치찌개 460Gx5개  ...    일반
# 29821      -  2023-05-29 04:39:05     1    다담 순두부찌개 양념 140G x12개  ...    일반
#
#          매출액                        자재명 초기자재수량  주문수량 취소수량  반품수량   배송유형  \
# 0          0  씨제이/명가 초사리곱창돌김 25G*2EA/상온      1     0    0     1   택배배송
# 1          0         우리쌀태양초고추장2KG/PP/상온      1     0    0     1   택배배송
# 2          0           백설/백설 소면 900G/상온      3     0    0     3   택배배송
# 3          0                하선정멸치액젓400g      1     0    0     1   택배배송
# 4      34110            갈색설탕3KG(6개입)/상온      6     6    0     0   택배배송
# ...      ...                        ...    ...   ...  ...   ...    ...
# 29817   3841        솥반 불고기버섯영양밥 200G/상온      1     1    0     0   택배배송
# 29818  11460                 햇반210g*6EA      2     2    0     0   택배배송
# 29819  21510     비비고/차돌된장찌개 460G_18입/상온      5     5    0     0  네이버위탁
# 29820  21800   비비고/돼지고기김치찌개 460G_18입/상온      5     5    0     0  네이버위탁
# 29821  27520     다담/순두부찌개양념 140G/24입/냉장     24    24    0     0   택배배송
#
#            마감구분  Day_of_Week
# 0            상온       Friday
# 1            상온       Friday
# 2            상온       Friday
# 3            상온       Friday
# 4            상온     Saturday
# ...         ...          ...
# 29817        상온       Sunday
# 29818        상온       Sunday
# 29819  풀필먼트(상온)       Sunday
# 29820  풀필먼트(상온)       Sunday
# 29821        냉동       Sunday
#
# [152458 rows x 23 columns]

# %%
# 월요일

df0 = merged_df.query('Day_of_Week == "Monday"')
df0
# Out:
#                   자사주문번호             거래처        주문일 사은품여부     출고예정일 주문/배송상태  \
# 7804   43262630504021744  외부몰_직거래_네이버(신) 2023-05-01     N  20230507   배송 완료
# 15777  43262630502986420  외부몰_직거래_네이버(신) 2023-05-01     N  20230503   배송 완료
# 16325  43262630502984828  외부몰_직거래_네이버(신) 2023-05-01     Y  20230503   배송 완료
# 16326  43262630502984828  외부몰_직거래_네이버(신) 2023-05-01     Y  20230503   배송 완료
# 16327  43262630502984828  외부몰_직거래_네이버(신) 2023-05-01     Y  20230503   배송 완료
# ...                  ...             ...        ...   ...       ...     ...
# 26340  43262630529436707  외부몰_직거래_네이버(신) 2023-05-29     N  20230530   배송 완료
# 26347  43262630529436701  외부몰_직거래_네이버(신) 2023-05-29     N  20230530   배송 완료
# 26348  43262630529436701  외부몰_직거래_네이버(신) 2023-05-29     N  20230530   배송 완료
# 26349  43262630529436701  외부몰_직거래_네이버(신) 2023-05-29     N  20230530   배송 완료
# 26350  43262630529436701  외부몰_직거래_네이버(신) 2023-05-29     N  20230530   배송 완료
#
#       클레임 상태              운송장등록일자  상품순번                                   상품명  \
# 7804       -  2023-05-04 15:18:01     1                         미역국밥 167G x7개
# 15777      -  2023-05-02 15:12:02     1                       비비고 육개장 300Gx6개
# 16325      -  2023-05-02 11:50:02     2                    비비고 소고기무국 500Gx18개
# 16326      -  2023-05-02 11:50:02     3                  비비고 소고기 미역국 500Gx18개
# 16327      -  2023-05-03 06:24:02     1                      비비고 본갈비탕 700Gx3개
# ...      ...                  ...   ...                                   ...
# 26340      -  2023-05-29 04:39:13     2                       햇반 흑미밥 210Gx12개
# 26347      -  2023-05-29 05:18:07     1                    햇반 쿡반 새우볶음밥420Gx4개
# 26348      -  2023-05-29 05:18:07     2            [네이버] 고메 클래식 콤비네이션 피자 405g
# 26349      -  2023-05-29 05:18:07     3  햇반 쿡반 김치치즈주먹밥 500Gx2개+불고기주먹밥 500Gx2개
# 26350      -  2023-05-29 05:18:07     3  햇반 쿡반 김치치즈주먹밥 500Gx2개+불고기주먹밥 500Gx2개
#
#        ...  상품타입    매출액                      자재명 초기자재수량  주문수량 취소수량  반품수량  \
# 7804   ...    일반  18600  햇반/컵반 미역국밥 167G(18입)/상온      7     7    0     0
# 15777  ...    일반  17000       비비고/육개장300G_온라인/상온      6     6    0     0
# 16325  ...    일반  53250    비비고/소고기무국 500G_18입/상온     18    18    0     0
# 16326  ...    일반  47470      비비고/미역국 500G_18입/상온     18    18    0     0
# 16327  ...    일반  27170         비비고/본갈비탕 700G/냉동      3     3    0     0
# ...    ...   ...    ...                      ...    ...   ...  ...   ...
# 26340  ...    일반  15980        햇반/흑미밥 210G*12/상온      1     1    0     0
# 26347  ...    일반  24180    햇반/새우볶음밥420G_2P_QI/냉동      4     4    0     0
# 26348  ...    일반  10310  고메 클래식 콤비네이션 피자 405G/냉동      2     2    0     0
# 26349  ...    일반  13533     햇반/불고기주먹밥 500G_UJ/냉동      2     2    0     0
# 26350  ...    일반  12027    햇반/김치치즈주먹밥 500G_BC/냉동      2     2    0     0
#
#         배송유형      마감구분  Day_of_Week
# 7804    택배배송        상온       Monday
# 15777   택배배송        상온       Monday
# 16325  네이버위탁  풀필먼트(상온)       Monday
# 16326  네이버위탁  풀필먼트(상온)       Monday
# 16327   택배배송        냉동       Monday
# ...      ...       ...          ...
# 26340   택배배송        상온       Monday
# 26347   택배배송        냉동       Monday
# 26348   택배배송        냉동       Monday
# 26349   택배배송        냉동       Monday
# 26350   택배배송        냉동       Monday
#
# [32379 rows x 23 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 요일별 상품 구매 횟수를 세는 DataFrame 생성
cnt = merged_df.groupby(['Day_of_Week','상품명']).size().reset_index(name='cnt')

# %%
# 요일별 '가장 많이 구매'하는 상품 추출
most_each_day = cnt.loc[cnt.groupby('Day_of_Week')['cnt'].idxmax()]
most_each_day
# Out:
#      Day_of_Week               상품명   cnt
# 175       Friday  [네이버] 햇반210Gx36개  1361
# 1713      Monday    스팸클래식 200Gx10개  6957
# 2138    Saturday  [네이버] 햇반210Gx36개  1489
# 2979      Sunday  [네이버] 햇반210Gx36개  2054
# 3878    Thursday  [네이버] 햇반210Gx36개  1960
# 4861     Tuesday  [네이버] 햇반210Gx36개  3642
# 6682   Wednesday       햇반 210Gx24개  3642

# %%
# 요일 순서를 정의 (월요일부터 일요일까지의 순서)
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# 요일별로 데이터 정렬
most_each_day['Day_of_Week'] = pd.Categorical(most_each_day['Day_of_Week'], categories=weekday_order, ordered=True)
df_sorted = most_each_day.sort_values(by='Day_of_Week')
df_sorted
# Out:
#      Day_of_Week               상품명   cnt
# 1713      Monday    스팸클래식 200Gx10개  6957
# 4861     Tuesday  [네이버] 햇반210Gx36개  3642
# 6682   Wednesday       햇반 210Gx24개  3642
# 3878    Thursday  [네이버] 햇반210Gx36개  1960
# 175       Friday  [네이버] 햇반210Gx36개  1361
# 2138    Saturday  [네이버] 햇반210Gx36개  1489
# 2979      Sunday  [네이버] 햇반210Gx36개  2054

# %% [markdown]
# ### *대부분 햇반 210Gx36개를 많이 구매함*

# %%
df_sorted.plot(kind='bar', x='Day_of_Week',y='cnt',color='green',rot=45,figsize=(10,5))
# Out:
# <Axes: xlabel='Day_of_Week'>

# %% [markdown]
# ##### 두번째로 많이 구매한 상품은 ?

# %%
# 각 요일별로 구매 횟수를 기준으로 내림차순 정렬
sorted_day_p_cnt = cnt.sort_values(by=['Day_of_Week', 'cnt'], ascending=[True, False])
sorted_day_p_cnt
# Out:
#      Day_of_Week                          상품명   cnt
# 175       Friday             [네이버] 햇반210Gx36개  1361
# 722       Friday                  햇반 210Gx24개  1303
# 784       Friday            햇반 작은공기130G x 36개   389
# 320       Friday     고메 스윗치즈2판+토마토치즈2판+갈릭치즈2판   357
# 731       Friday            햇반 발아현미밥 210Gx36개   349
# ...          ...                          ...   ...
# 6867   Wednesday          햇반쿡반 닭갈비볶음밥 440Gx3개     1
# 6870   Wednesday          햇반쿡반 불고기주먹밥 500Gx3개     1
# 6871   Wednesday           햇반쿡반 새우볶음밥 420Gx4개     1
# 6875   Wednesday  행복한콩 2가지로만 국산콩두부 부침용180Gx3개     1
# 6877   Wednesday        행복한콩 폭신폭신 두부볼 750Gx1개     1
#
# [6881 rows x 3 columns]

# %%
# 두번째로 많이 구매한 상품
second_most_each_day = sorted_day_p_cnt.groupby('Day_of_Week').nth(1)
second_most_each_day
# Out:
#                            상품명   cnt
# Day_of_Week
# Friday             햇반 210Gx24개  1303
# Monday        [네이버] 햇반210Gx36개  2956
# Saturday           햇반 210Gx24개  1080
# Sunday       햇반 작은공기130G x 36개  1428
# Thursday           햇반 210Gx24개  1561
# Tuesday            햇반 210Gx24개  2286
# Wednesday     [네이버] 햇반210Gx36개  3301

# %%
# Day_of_Week -> 칼럼으로 변환
second_most_each_day = second_most_each_day.reset_index()
second_most_each_day
# Out:
#   Day_of_Week                상품명   cnt
# 0      Friday        햇반 210Gx24개  1303
# 1      Monday   [네이버] 햇반210Gx36개  2956
# 2    Saturday        햇반 210Gx24개  1080
# 3      Sunday  햇반 작은공기130G x 36개  1428
# 4    Thursday        햇반 210Gx24개  1561
# 5     Tuesday        햇반 210Gx24개  2286
# 6   Wednesday   [네이버] 햇반210Gx36개  3301

# %%
# 요일별로 데이터 정렬
second_most_each_day['Day_of_Week'] = pd.Categorical(second_most_each_day['Day_of_Week'], categories=weekday_order, ordered=True)
df_second_sorted = second_most_each_day.sort_values(by='Day_of_Week')
df_second_sorted
# Out:
#   Day_of_Week                상품명   cnt
# 1      Monday   [네이버] 햇반210Gx36개  2956
# 5     Tuesday        햇반 210Gx24개  2286
# 6   Wednesday   [네이버] 햇반210Gx36개  3301
# 4    Thursday        햇반 210Gx24개  1561
# 0      Friday        햇반 210Gx24개  1303
# 2    Saturday        햇반 210Gx24개  1080
# 3      Sunday  햇반 작은공기130G x 36개  1428

# %% [markdown]
# - 여전히 햇반이 많이 팔린 것을 알 수 있음

# %% [markdown]
# ### <span style='background-color: #fff5b1; color: #008000'>가장 많이 구매한 상품 매출액은 어떻게 될까?</span>

# %%
# day_product_sales = merged_df.groupby(['Day_of_Week', '상품명'])['매출액'].sum().reset_index()

# %%
# idx = day_product_sales.groupby('Day_of_Week')['매출액'].idxmax()
# most_product_sales = day_product_sales.loc[idx]

# most_product_sales

# %%
# 요일과 '상품명' 열을 기준으로 그룹화
# 각 요일별, 제품별 총 매출액과 상품 갯수 계산

day_product_sales = merged_df.groupby(['Day_of_Week', '상품명'])['매출액'].agg(['sum', 'count']).reset_index()
day_product_sales
# Out:
#      Day_of_Week                                     상품명      sum  count
# 0         Friday       BIG컵반 선택구매 (스팸마요,치킨마요,스팸김치,김치날치알)    11430      4
# 1         Friday                        CJ 교자만두1.41KGx2개    41730      2
# 2         Friday                          CJ 꼬마새우까스 250G    23280      2
# 3         Friday                 CJ 남원 가쓰오우동 933.2G(4인분)    23140      1
# 4         Friday                     CJ 동치미냉면육수 300Gx30개   197080      6
# ...          ...                                     ...      ...    ...
# 6876   Wednesday            행복한콩 2가지로만 국산콩두부 부침찌개300Gx2개    32910      2
# 6877   Wednesday                   행복한콩 폭신폭신 두부볼 750Gx1개    36970      1
# 6878   Wednesday                 현미귀리곤약밥 16개+귀리흑미곤약밥 16개  4807680    180
# 6879   Wednesday                            황태국밥170G x7개    35110      2
# 6880   Wednesday  흑미곤약밥 150Gx6+현미곤약밥 150Gx6+발아현미밥 210Gx6    92180      6
#
# [6881 rows x 4 columns]

# %%
# 요일별로 가장 많은 상품 갯수와 
# 매출액을 가진 상품 추출
idx = day_product_sales.groupby('Day_of_Week')['count'].idxmax()
most_product_sales = day_product_sales.loc[idx]

most_product_sales
# Out:
#      Day_of_Week               상품명        sum  count
# 175       Friday  [네이버] 햇반210Gx36개   47200700   1361
# 1713      Monday    스팸클래식 200Gx10개  141505020   6957
# 2138    Saturday  [네이버] 햇반210Gx36개   49876550   1489
# 2979      Sunday  [네이버] 햇반210Gx36개   69554870   2054
# 3878    Thursday  [네이버] 햇반210Gx36개   73550750   1960
# 4861     Tuesday  [네이버] 햇반210Gx36개  133327450   3642
# 6682   Wednesday       햇반 210Gx24개   85259730   3642

# %%
# sum -> 매출액 컬럼명 변경
most_product_sales.rename(columns={'sum': '매출액'}, inplace=True)
most_product_sales
# Out:
#      Day_of_Week               상품명        매출액  count
# 175       Friday  [네이버] 햇반210Gx36개   47200700   1361
# 1713      Monday    스팸클래식 200Gx10개  141505020   6957
# 2138    Saturday  [네이버] 햇반210Gx36개   49876550   1489
# 2979      Sunday  [네이버] 햇반210Gx36개   69554870   2054
# 3878    Thursday  [네이버] 햇반210Gx36개   73550750   1960
# 4861     Tuesday  [네이버] 햇반210Gx36개  133327450   3642
# 6682   Wednesday       햇반 210Gx24개   85259730   3642

# %% [markdown]
# ### 요일 별 매출액 비교하기

# %%
# 각 요일별 매출액 합산
daily_sales = merged_df.groupby('Day_of_Week')['매출액'].sum()
daily_sales
# Out:
# Day_of_Week
# Friday       318405990
# Monday       819599670
# Saturday     272698160
# Sunday       411013400
# Thursday     417930610
# Tuesday      705752484
# Wednesday    771164595
# Name: 매출액, dtype: int64

# %%
daily_sales.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7 entries, Friday to Wednesday
# Series name: 매출액
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      int64
# dtypes: int64(1)
# memory usage: 412.0+ bytes

# %%
daily_sales = daily_sales.reset_index()
daily_sales
# Out:
#   Day_of_Week        매출액
# 0      Friday  318405990
# 1      Monday  819599670
# 2    Saturday  272698160
# 3      Sunday  411013400
# 4    Thursday  417930610
# 5     Tuesday  705752484
# 6   Wednesday  771164595

# %%
# 요일별로 데이터 정렬
daily_sales['Day_of_Week'] = pd.Categorical(daily_sales['Day_of_Week'], categories=weekday_order, ordered=True)
daily_sorted = daily_sales.sort_values(by='Day_of_Week')
daily_sorted
# Out:
#   Day_of_Week        매출액
# 1      Monday  819599670
# 5     Tuesday  705752484
# 6   Wednesday  771164595
# 4    Thursday  417930610
# 0      Friday  318405990
# 2    Saturday  272698160
# 3      Sunday  411013400

# %%
#시각화를 위한 한글 폰트 설정
plt.rc('font', family= 'Malgun Gothic')

# %%
plt.figure(figsize=(10, 6))
plt.plot(daily_sorted['Day_of_Week'], daily_sorted['매출액'], marker='o',color='green', label='매출액')
plt.title('Total Sales by Day of Week')

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 최종

# %%
merge_df = pd.merge(most_product_sales,daily_sales, on='Day_of_Week', how='inner')
merge_df
# Out:
#   Day_of_Week               상품명      매출액_x  count      매출액_y
# 0      Friday  [네이버] 햇반210Gx36개   47200700   1361  318405990
# 1      Monday    스팸클래식 200Gx10개  141505020   6957  819599670
# 2    Saturday  [네이버] 햇반210Gx36개   49876550   1489  272698160
# 3      Sunday  [네이버] 햇반210Gx36개   69554870   2054  411013400
# 4    Thursday  [네이버] 햇반210Gx36개   73550750   1960  417930610
# 5     Tuesday  [네이버] 햇반210Gx36개  133327450   3642  705752484
# 6   Wednesday       햇반 210Gx24개   85259730   3642  771164595

# %%
# 요일별로 데이터 정렬
merge_df['Day_of_Week'] = pd.Categorical(merge_df['Day_of_Week'], categories=weekday_order, ordered=True)
merge_sorted = merge_df.sort_values(by='Day_of_Week')
merge_sorted
# Out:
#   Day_of_Week               상품명      매출액_x  count      매출액_y
# 1      Monday    스팸클래식 200Gx10개  141505020   6957  819599670
# 5     Tuesday  [네이버] 햇반210Gx36개  133327450   3642  705752484
# 6   Wednesday       햇반 210Gx24개   85259730   3642  771164595
# 4    Thursday  [네이버] 햇반210Gx36개   73550750   1960  417930610
# 0      Friday  [네이버] 햇반210Gx36개   47200700   1361  318405990
# 2    Saturday  [네이버] 햇반210Gx36개   49876550   1489  272698160
# 3      Sunday  [네이버] 햇반210Gx36개   69554870   2054  411013400

# %% [markdown]
# 요일 별 매출액 - 가장 많이 구매한 상품 매출액

# %%
# 매출액의 차이 계산
merge_sorted['Sales_Difference'] = merge_sorted['매출액_x'] - merge_sorted['매출액_y']


# 그래프 그리기
plt.figure(figsize=(13, 6))
plt.plot(merge_sorted['Day_of_Week'], merge_sorted['Sales_Difference'], marker='o', color='b', label='매출액 차이')
plt.legend()
plt.show()
# Out:
# C:\Users\HAEUNSEO\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 2. 사은품여부

# %%
merged_df.isna().sum()
# Out:
# 자사주문번호            0
# 거래처               0
# 주문일               0
# 사은품여부             0
# 출고예정일             0
# 주문/배송상태           0
# 클레임 상태            0
# 운송장등록일자        4311
# 상품순번              0
# 상품명               0
# 상품수량              0
# 덤상품수량             0
# 상품유형            705
# 상품타입            705
# 매출액               0
# 자재명             705
# 초기자재수량            0
# 주문수량              0
# 취소수량              0
# 반품수량              0
# 배송유형              0
# 마감구분              0
# Day_of_Week       0
# dtype: int64

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152458 entries, 0 to 29821
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   자사주문번호       152458 non-null  int64
#  1   거래처          152458 non-null  object
#  2   주문일          152458 non-null  datetime64[ns]
#  3   사은품여부        152458 non-null  object
#  4   출고예정일        152458 non-null  int64
#  5   주문/배송상태      152458 non-null  object
#  6   클레임 상태       152458 non-null  object
#  7   운송장등록일자      148147 non-null  object
#  8   상품순번         152458 non-null  int64
#  9   상품명          152458 non-null  object
#  10  상품수량         152458 non-null  int64
#  11  덤상품수량        152458 non-null  int64
#  12  상품유형         151753 non-null  object
#  13  상품타입         151753 non-null  object
#  14  매출액          152458 non-null  int64
#  15  자재명          151753 non-null  object
#  16  초기자재수량       152458 non-null  int64
#  17  주문수량         152458 non-null  int64
#  18  취소수량         152458 non-null  int64
#  19  반품수량         152458 non-null  int64
#  20  배송유형         152458 non-null  object
#  21  마감구분         152458 non-null  object
#  22  Day_of_Week  152458 non-null  object
# dtypes: datetime64[ns](1), int64(10), object(12)
# memory usage: 27.9+ MB

# %%
merged_df.query("사은품여부=='Y'")
# Out:
#                   자사주문번호             거래처        주문일 사은품여부     출고예정일 주문/배송상태  \
# 149    43262630506052516  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# 150    43262630506052516  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# 496    43262630506051097  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# 497    43262630506051097  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# 852    43262630506049178  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# ...                  ...             ...        ...   ...       ...     ...
# 29689  43262630528427623  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
# 29690  43262630528427623  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
# 29695  43262630528427618  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
# 29696  43262630528427618  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
# 29697  43262630528427618  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
#
#       클레임 상태              운송장등록일자  상품순번                            상품명  ...  \
# 149        -  2023-05-08 06:03:04     1               비비고 본갈비탕 700Gx3개  ...
# 150        -  2023-05-08 06:03:04     1            [사은품] 비비고 특설렁탕 700G  ...
# 496        -  2023-05-08 06:03:03     1               비비고 본갈비탕 700Gx3개  ...
# 497        -  2023-05-08 06:03:03     1            [사은품] 비비고 특설렁탕 700G  ...
# 852        -  2023-05-07 10:20:02     2                  스팸클래식 340Gx5개  ...
# ...      ...                  ...   ...                            ...  ...
# 29689      -  2023-05-28 13:33:02     1  [1주 SET] 햇반 그레인보울 병아리콩3+할라피뇨3  ...
# 29690      -  2023-05-28 13:33:02     1             [사은품] 그레인보울x아몬드브리즈  ...
# 29695      -  2023-05-28 13:33:02     1  [1주 SET] 햇반 그레인보울 병아리콩3+할라피뇨3  ...
# 29696      -  2023-05-28 13:33:02     1  [1주 SET] 햇반 그레인보울 병아리콩3+할라피뇨3  ...
# 29697      -  2023-05-28 13:33:02     1             [사은품] 그레인보울x아몬드브리즈  ...
#
#        상품타입    매출액                 자재명 초기자재수량  주문수량 취소수량  반품수량   배송유형  \
# 149      일반  26370    비비고/본갈비탕 700G/냉동      3     3    0     0   택배배송
# 150     NaN      0                 NaN      1     1    0     0   택배배송
# 496      일반  28300    비비고/본갈비탕 700G/냉동      3     3    0     0   택배배송
# 497     NaN      0                 NaN      1     1    0     0   택배배송
# 852      일반  19360           스팸클래식340g      5     5    0     0  네이버위탁
# ...     ...    ...                 ...    ...   ...  ...   ...    ...
# 29689    일반  29970  병아리콩 그레인보울 160G/상온      9     9    0     0   택배배송
# 29690   NaN      0                 NaN      3     3    0     0   택배배송
# 29695    일반  17980  할라피뇨 그레인보울 160G/상온      6     6    0     0   택배배송
# 29696    일반  17980  병아리콩 그레인보울 160G/상온      6     6    0     0   택배배송
# 29697   NaN      0                 NaN      2     2    0     0   택배배송
#
#            마감구분  Day_of_Week
# 149          냉동     Saturday
# 150          냉동     Saturday
# 496          냉동     Saturday
# 497          냉동     Saturday
# 852    풀필먼트(상온)     Saturday
# ...         ...          ...
# 29689        상온       Sunday
# 29690        상온       Sunday
# 29695        상온       Sunday
# 29696        상온       Sunday
# 29697        상온       Sunday
#
# [2287 rows x 23 columns]

# %%
result = merged_df[merged_df['상품명'].str.contains('사은품')]
result
# Out:
#                   자사주문번호             거래처        주문일 사은품여부     출고예정일 주문/배송상태  \
# 150    43262630506052516  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# 497    43262630506051097  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# 518    43262630506051081  외부몰_직거래_네이버(신) 2023-05-06     N  20230508   배송 완료
# 853    43262630506049178  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# 854    43262630506049178  외부몰_직거래_네이버(신) 2023-05-06     Y  20230508   배송 완료
# ...                  ...             ...        ...   ...       ...     ...
# 29505  43262630528428511  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
# 29595  43262630528427683  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
# 29682  43262630528427629  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
# 29690  43262630528427623  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
# 29697  43262630528427618  외부몰_직거래_네이버(신) 2023-05-28     Y  20230530   배송 완료
#
#       클레임 상태              운송장등록일자  상품순번  \
# 150        -  2023-05-08 06:03:04     1
# 497        -  2023-05-08 06:03:03     1
# 518        -  2023-05-08 15:12:03     5
# 853        -  2023-05-08 06:03:03     1
# 854        -  2023-05-08 06:03:03     1
# ...      ...                  ...   ...
# 29505      -  2023-05-28 13:33:03     1
# 29595      -  2023-05-28 13:33:02     1
# 29682      -  2023-05-28 13:33:02     1
# 29690      -  2023-05-28 13:33:02     1
# 29697      -  2023-05-28 13:33:02     1
#
#                                                      상품명  ...  상품타입    매출액  \
# 150                                  [사은품] 비비고 특설렁탕 700G  ...   NaN      0
# 497                                  [사은품] 비비고 특설렁탕 700G  ...   NaN      0
# 518    [네이버]백설 캠핑에딱그릴후랑크마늘맛 300gx2번들 X2개 + [사은품] 비비고 ...  ...    일반   8900
# 853                   비비고 왕교자 1.4kg+[사은품]햇반쿡반 새우볶음밥(1인분)  ...    일반  21510
# 854                                 [사은품][네이버]햇반쿡반 새우볶음밥  ...   NaN      0
# ...                                                  ...  ...   ...    ...
# 29505                                 [사은품] 그레인보울x아몬드브리즈  ...   NaN      0
# 29595                                 [사은품] 그레인보울x아몬드브리즈  ...   NaN      0
# 29682                                 [사은품] 그레인보울x아몬드브리즈  ...   NaN      0
# 29690                                 [사은품] 그레인보울x아몬드브리즈  ...   NaN      0
# 29697                                 [사은품] 그레인보울x아몬드브리즈  ...   NaN      0
#
#                          자재명 초기자재수량  주문수량 취소수량  반품수량  배송유형  마감구분  Day_of_Week
# 150                      NaN      1     1    0     0  택배배송    냉동     Saturday
# 497                      NaN      1     1    0     0  택배배송    냉동     Saturday
# 518    백설/캠핑에딱그릴후랑크마늘맛300G*2      2     2    0     0  택배배송    냉장     Saturday
# 853         비비고/왕교자 1.4KG/냉동      2     2    0     0  택배배송    냉동     Saturday
# 854                      NaN      1     1    0     0  택배배송    냉동     Saturday
# ...                      ...    ...   ...  ...   ...   ...   ...          ...
# 29505                    NaN      1     1    0     0  택배배송    상온       Sunday
# 29595                    NaN      1     1    0     0  택배배송    상온       Sunday
# 29682                    NaN      1     1    0     0  택배배송    상온       Sunday
# 29690                    NaN      3     3    0     0  택배배송    상온       Sunday
# 29697                    NaN      2     2    0     0  택배배송    상온       Sunday
#
# [953 rows x 23 columns]

# %%
result.groupby('상품명').size().sort_values(ascending=False)
# Out:
# 상품명
# [사은품] 그레인보울x아몬드브리즈                                        278
# [사은품]비비고 특설렁탕 700G                                        205
# 비비고 본갈비탕 700Gx4개+[사은품]특설렁탕x2개                             205
# [사은품] 비비고 특설렁탕 700G                                       194
# [네이버]백설 캠핑에딱그릴후랑크마늘맛 300gx2번들 X2개 + [사은품] 비비고 김치볶음 80g     25
# [사은품][네이버]햇반쿡반 새우볶음밥                                       17
# 비비고 왕교자 1.4kg+[사은품]햇반쿡반 새우볶음밥(1인분)                         17
# [사은품]비비고테이블 부직포 가방                                          5
# [사은품]비비고테이블냉동국물세트리플렛                                        5
# [사은품]해찬들 찍장 쌈장(300g)                                        1
# 햇반 솥반 미미달 기획 전불뿌꿀x2EA [사은품]미미달 코스터                          1
# dtype: int64

# %% [markdown]
# ### 사은품으로 *그레인보울x아몬드브리즈*를 가장 많이 받음
