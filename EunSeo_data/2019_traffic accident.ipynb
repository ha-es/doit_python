# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus'] = False

# %%
accident = pd.read_csv('2019_traffic accident.csv', encoding='EUC-KR')
accident.head()
# Out:
#       구분    도로종류  사고(건)  사망(명)  부상(명)
# 0  2017년    일반국도    363     19    698
# 1  2017년     지방도    230     10    451
# 2  2017년  특별광역시도    590     12   1189
# 3  2017년      시도    577     11   1125
# 4  2017년      군도    101      3    169

# %%
ad = pd.read_csv('traffic accident.csv', encoding='EUC-KR')
ad
# Out:
#       연도    사고   사망    부상
# 0   2000  3910  569  2845
# 1   2001  3638  456  2331
# 2   2002  3957  421  2115
# 3   2003  3585  348  1843
# 4   2004  3242  300  1555
# 5   2005  2880  249  1170
# 6   2006  2583  284  1131
# 7   2007  2550  283  1114
# 8   2008  2449  265   955
# 9   2009  2374  248  1031
# 10  2010  2368  353   983
# 11  2011  2640  265  1731
# 12  2012  2600  343  1619
# 13  2013  2496  264  1253
# 14  2014  2395  253  1148
# 15  2015  2251  223  1054
# 16  2016  2195  239  1424
# 17  2017  2145  214   911
# 18  2018  2030  227   858
# 19  2019  1931  176   830
# 20  2020  1834  179   861
# 21  2021  1735  171   794

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      21 non-null     object
#  1   도로종류    21 non-null     object
#  2   사고(건)   21 non-null     int64
#  3   사망(명)   21 non-null     int64
#  4   부상(명)   21 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 968.0+ bytes

# %%
accident_2019 = accident.query('구분 == "2019년"')
accident_2019
# Out:
#        구분    도로종류  사고(건)  사망(명)  부상(명)
# 14  2019년    일반국도    498     29    964
# 15  2019년     지방도    300     18    587
# 16  2019년  특별광역시도    825      7   1594
# 17  2019년      시도    876     17   1629
# 18  2019년      군도    116      8    184
# 19  2019년    고속국도    147     20    296
# 20  2019년      기타    125      2    206

# %%
accident_2019['total'] = accident_2019['사고(건)'] + accident_2019['사망(명)'] + accident_2019['부상(명)']
accident_2019
# Out:
# C:\Users\HAEUNSEO\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        구분    도로종류  사고(건)  사망(명)  부상(명)  total
# 14  2019년    일반국도    498     29    964   1491
# 15  2019년     지방도    300     18    587    905
# 16  2019년  특별광역시도    825      7   1594   2426
# 17  2019년      시도    876     17   1629   2522
# 18  2019년      군도    116      8    184    308
# 19  2019년    고속국도    147     20    296    463
# 20  2019년      기타    125      2    206    333

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.barplot( data=accident_2019, x='도로종류', y='total');
